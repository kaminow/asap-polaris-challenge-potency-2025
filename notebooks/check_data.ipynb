# %%
import matplotlib.pyplot as plt
import pandas
import seaborn as sns

# %%
df_sars = pandas.read_csv(
    "../raw_data/potency/SARS-CoV-2-Mpro_potencies_CONFIDENTIAL.csv"
)
print(df_sars.columns)
df_sars
# Out:
# Index(['SARS-CoV-2-MPro_fluorescence-dose-response_weizmann: IC50 (µM)',
#        'SARS-CoV-2-MPro_fluorescence-dose-response_weizmann: IC50 CI (Lower) (µM)',
#        'SARS-CoV-2-MPro_fluorescence-dose-response_weizmann: IC50 CI (Upper) (µM)',
#        'SARS-CoV-2-MPro_fluorescence-dose-response_weizmann: Hill slope',
#        'SARS-CoV-2-MPro_fluorescence-dose-response_weizmann: pIC50 (log10M)',
#        'Molecule Name', 'CXSMILES (CDD Compatible)', 'Batch Created Date'],
#       dtype='object')
#      SARS-CoV-2-MPro_fluorescence-dose-response_weizmann: IC50 (µM)  \
# 0                                                13.440
# 1                                                 7.993
# 2                                                48.046
# 3                                                31.129
# 4                                                27.025
# ...                                                 ...
# 1325                                           > 99.500
# ...

# %%
df_sars["Batch Created Date"].unique()
# Out:
# array(['2024-07-08', '2024-07-15', '2024-07-22', '2024-07-29',
#        '2024-08-05', '2024-08-12', '2024-08-19', '2024-08-26',
#        '2024-09-02', '2024-09-09', '2024-09-16', '2024-09-23',
#        '2024-09-30', '2024-10-07', '2023-12-12', '2023-11-27',
#        '2023-09-11', '2023-08-21', '2023-08-08', '2023-07-24',
#        '2023-07-18', '2023-07-17', '2023-07-05', '2023-06-29',
#        '2023-06-21', '2023-06-13', '2023-06-07', '2023-05-30',
#        '2023-05-23', '2023-05-17', '2023-05-06', '2023-05-01',
#        '2023-04-25', '2023-04-21', '2023-04-16', '2023-04-05',
#        '2023-03-29', '2023-03-22', '2023-03-15', '2023-03-09',
#        '2023-03-01', '2023-02-23', '2023-02-16', '2023-02-08',
#        '2023-02-01', '2023-01-25', '2023-01-18', '2023-01-13',
#        '2022-12-27', '2022-12-14', '2022-12-07', '2022-12-02',
#        '2022-11-19', '2022-11-09', '2022-10-27', '2022-10-23',
#        '2022-10-03', '2022-09-18', '2022-08-28', '2022-08-10',
# ...

# %%
duplicates = [g for _, g in df_sars.groupby("Molecule Name") if len(g) > 1]
len(duplicates)
# Out:
# 98

# %%
duplicates[0]
# Out:
#      SARS-CoV-2-MPro_fluorescence-dose-response_weizmann: IC50 (µM)  \
# 996                                               0.009
# 997                                               0.011
# 998                                               0.008
# 999                                               0.008
# 1000                                              0.008
# ...                                                 ...
# 1090                                              0.005
# 1091                                              0.010
# 1092                                              0.104
# 1093                                              0.014
# 1094                                            < 0.050
#
#       SARS-CoV-2-MPro_fluorescence-dose-response_weizmann: IC50 CI (Lower) (µM)  \
# 996                                               0.009
# 997                                               0.010
# 998                                               0.007
# ...

# %%
df_sars_parsed = pandas.read_csv("../ml_datasets/sars_parsed.csv")
print(df_sars_parsed.columns)
df_sars_parsed
# Out:
# Index(['SARS-CoV-2-MPro_fluorescence-dose-response_weizmann: IC50 (µM)',
#        'SARS-CoV-2-MPro_fluorescence-dose-response_weizmann: IC50 CI (Lower) (µM)',
#        'SARS-CoV-2-MPro_fluorescence-dose-response_weizmann: IC50 CI (Upper) (µM)',
#        'SARS-CoV-2-MPro_fluorescence-dose-response_weizmann: Hill slope',
#        'SARS-CoV-2-MPro_fluorescence-dose-response_weizmann: pIC50 (log10M)',
#        'Molecule Name', 'CXSMILES (CDD Compatible)', 'Batch Created Date',
#        'smiles', 'name', 'achiral', 'racemic', 'enantiopure', 'semiquant',
#        'invalid', 'IC50 (M)', 'IC50_stderr (M)', 'IC50_95ci_lower (M)',
#        'IC50_95ci_upper (M)', 'pIC50', 'pIC50_stderr', 'pIC50_range',
#        'pIC50_95ci_lower', 'pIC50_95ci_upper', 'exp_binding_affinity_kcal_mol',
#        'exp_binding_affinity_kT', 'exp_binding_affinity_kcal_mol_95ci_lower',
#        'exp_binding_affinity_kT_95ci_lower',
#        'exp_binding_affinity_kcal_mol_95ci_upper',
# ...

# %%
sum(["|" in smi for smi in df_sars_parsed["smiles"]])
# Out:
# 0

# %%
df_sars.loc[df_sars["Molecule Name"] == "ASAP-0000141", :]
# Out:
#     SARS-CoV-2-MPro_fluorescence-dose-response_weizmann: IC50 (µM)  \
# 995                                            > 9.990
#
#      SARS-CoV-2-MPro_fluorescence-dose-response_weizmann: IC50 CI (Lower) (µM)  \
# 995                                                NaN
#
#      SARS-CoV-2-MPro_fluorescence-dose-response_weizmann: IC50 CI (Upper) (µM)  \
# 995                                                NaN
#
#      SARS-CoV-2-MPro_fluorescence-dose-response_weizmann: Hill slope  \
# 995                                                NaN
#
#     SARS-CoV-2-MPro_fluorescence-dose-response_weizmann: pIC50 (log10M)  \
# 995                                             < 5.00
#
#     Molecule Name                          CXSMILES (CDD Compatible)  \
# 995  ASAP-0000141  COC[C@]1(C)C(=O)N(C2=CN=CC3=CC=CC=C23)C(=O)N1C...
#
#     Batch Created Date
# 995         2022-08-09
